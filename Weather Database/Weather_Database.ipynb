# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lats,lngs)

# %%
coordinates=list(lat_lngs)

# %%
from citipy import citipy

# %%
cities=[]
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
import requests
from config import weather_api_key

# %%
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data=[]
print("Beginning Data Retrieval")
print("----")
record_count=1
set_count=1

for i, city in enumerate(cities):
    if (i % 50==0 and i >= 50):
        set_count+=1
        record_count=1
    city_url = url + "&q=" +city.replace(" ", "+")
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count+=1
    
    try:
        city_weather=requests.get(city_url).json()
        city_lat=city_weather["coord"]["lat"]
        city_lng=city_weather["coord"]["lon"]
        city_max_temp=city_weather["main"]["temp_max"]
        city_humidity=city_weather["main"]["humidity"]
        city_clouds=city_weather["clouds"]["all"]
        city_wind=city_weather["wind"]["speed"]
        city_country=city_weather["sys"]["country"]
        city_weatherdesc=city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                         "Country":city_country,
                         "Lat": city_lat,
                         "Lng":city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_weatherdesc
                         })
    except:
        print("City not found. Skipping")
        pass
print("---")
print("Data Retrival Completed")
print("---")
# Out:
# Beginning Data Retrieval
# ----
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | saint anthony
# Processing Record 6 of Set 1 | saint-joseph
# Processing Record 7 of Set 1 | ossora
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | korla
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | florida
# Processing Record 20 of Set 1 | hongjiang
# Processing Record 21 of Set 1 | naze
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | broome
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | lodja
# Processing Record 28 of Set 1 | auki
# Processing Record 29 of Set 1 | cangzhou
# Processing Record 30 of Set 1 | valparaiso
# Processing Record 31 of Set 1 | sola
# Processing Record 32 of Set 1 | tautira
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | miri
# Processing Record 35 of Set 1 | salvador
# Processing Record 36 of Set 1 | yarmouth
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | coquimbo
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | marondera
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | ornskoldsvik
# Processing Record 44 of Set 1 | eisenerz
# Processing Record 45 of Set 1 | tecoanapa
# Processing Record 46 of Set 1 | nchelenge
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | aswan
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | ayan
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | rio grande
# Processing Record 3 of Set 2 | hargeysa
# Processing Record 4 of Set 2 | eureka
# Processing Record 5 of Set 2 | dedza
# Processing Record 6 of Set 2 | asau
# Processing Record 7 of Set 2 | papara
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | samarai
# Processing Record 10 of Set 2 | dali
# Processing Record 11 of Set 2 | limoges
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | kruisfontein
# Processing Record 16 of Set 2 | mayo
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | goderich
# Processing Record 19 of Set 2 | sungurlu
# Processing Record 20 of Set 2 | bolitoc
# Processing Record 21 of Set 2 | portland
# Processing Record 22 of Set 2 | salaga
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | kununurra
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping
# Processing Record 27 of Set 2 | souillac
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | celestun
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | killarney
# Processing Record 32 of Set 2 | suffolk
# Processing Record 33 of Set 2 | los banos
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | samusu
# City not found. Skipping
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | borazjan
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | araouane
# Processing Record 41 of Set 2 | brignoles
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | avera
# Processing Record 45 of Set 2 | neryungri
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | yanam
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping
# Processing Record 49 of Set 2 | seoul
# Processing Record 50 of Set 2 | mahajanga
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | middelkerke
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | kemin
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | huarmey
# Processing Record 8 of Set 3 | rong kwang
# Processing Record 9 of Set 3 | santa cruz
# Processing Record 10 of Set 3 | urumqi
# Processing Record 11 of Set 3 | hofn
# Processing Record 12 of Set 3 | esmeralda
# Processing Record 13 of Set 3 | katsuura
# Processing Record 14 of Set 3 | nioro
# Processing Record 15 of Set 3 | hammerfest
# Processing Record 16 of Set 3 | arman
# Processing Record 17 of Set 3 | bairiki
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | iralaya
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | esperance
# Processing Record 22 of Set 3 | saint-louis
# Processing Record 23 of Set 3 | louisbourg
# City not found. Skipping
# Processing Record 24 of Set 3 | jacqueville
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping
# Processing Record 26 of Set 3 | manicore
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | poum
# Processing Record 29 of Set 3 | albany
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | bandarbeyla
# Processing Record 33 of Set 3 | guatire
# Processing Record 34 of Set 3 | aklavik
# Processing Record 35 of Set 3 | victoria point
# Processing Record 36 of Set 3 | yerbogachen
# Processing Record 37 of Set 3 | vaitupu
# City not found. Skipping
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | cozumel
# Processing Record 40 of Set 3 | camara de lobos
# Processing Record 41 of Set 3 | grand river south east
# City not found. Skipping
# Processing Record 42 of Set 3 | afanasyevo
# City not found. Skipping
# Processing Record 43 of Set 3 | grindavik
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | san cristobal
# Processing Record 46 of Set 3 | guanare
# Processing Record 47 of Set 3 | vila franca do campo
# Processing Record 48 of Set 3 | kahului
# Processing Record 49 of Set 3 | bluff
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | diu
# Processing Record 2 of Set 4 | ialibu
# Processing Record 3 of Set 4 | ballina
# Processing Record 4 of Set 4 | marshalltown
# Processing Record 5 of Set 4 | malpe
# Processing Record 6 of Set 4 | porto walter
# Processing Record 7 of Set 4 | kibre mengist
# Processing Record 8 of Set 4 | marsabit
# Processing Record 9 of Set 4 | turukhansk
# Processing Record 10 of Set 4 | caborca
# Processing Record 11 of Set 4 | yanan
# City not found. Skipping
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | matadi
# Processing Record 14 of Set 4 | shimoda
# Processing Record 15 of Set 4 | sosnovoborsk
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | san juan
# Processing Record 18 of Set 4 | ust-nera
# Processing Record 19 of Set 4 | filadelfia
# Processing Record 20 of Set 4 | padang
# Processing Record 21 of Set 4 | thinadhoo
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping
# Processing Record 23 of Set 4 | abu samrah
# Processing Record 24 of Set 4 | iaciara
# Processing Record 25 of Set 4 | laguna
# Processing Record 26 of Set 4 | barcelos
# Processing Record 27 of Set 4 | ponorogo
# Processing Record 28 of Set 4 | komarikhinskiy
# Processing Record 29 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 4 | jalu
# Processing Record 31 of Set 4 | talnakh
# Processing Record 32 of Set 4 | kawalu
# Processing Record 33 of Set 4 | evansville
# Processing Record 34 of Set 4 | northam
# Processing Record 35 of Set 4 | iqaluit
# Processing Record 36 of Set 4 | nantucket
# Processing Record 37 of Set 4 | mayor pablo lagerenza
# Processing Record 38 of Set 4 | linjiang
# Processing Record 39 of Set 4 | palabuhanratu
# City not found. Skipping
# Processing Record 40 of Set 4 | kushima
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | tuktoyaktuk
# Processing Record 43 of Set 4 | ternate
# Processing Record 44 of Set 4 | senekal
# Processing Record 45 of Set 4 | north bend
# Processing Record 46 of Set 4 | cervo
# Processing Record 47 of Set 4 | victoria
# Processing Record 48 of Set 4 | airai
# Processing Record 49 of Set 4 | illoqqortoormiut
# City not found. Skipping
# Processing Record 50 of Set 4 | sur
# Processing Record 1 of Set 5 | fairbanks
# Processing Record 2 of Set 5 | asasa
# Processing Record 3 of Set 5 | udachnyy
# Processing Record 4 of Set 5 | pailon
# Processing Record 5 of Set 5 | shahdol
# Processing Record 6 of Set 5 | norman wells
# Processing Record 7 of Set 5 | comodoro rivadavia
# Processing Record 8 of Set 5 | willow grove
# Processing Record 9 of Set 5 | novopskov
# Processing Record 10 of Set 5 | half moon bay
# Processing Record 11 of Set 5 | waipawa
# Processing Record 12 of Set 5 | port elizabeth
# Processing Record 13 of Set 5 | pozo colorado
# Processing Record 14 of Set 5 | ulladulla
# Processing Record 15 of Set 5 | malartic
# Processing Record 16 of Set 5 | pangnirtung
# Processing Record 17 of Set 5 | milton
# Processing Record 18 of Set 5 | boa vista
# Processing Record 19 of Set 5 | bereda
# Processing Record 20 of Set 5 | barrow
# Processing Record 21 of Set 5 | acapulco
# Processing Record 22 of Set 5 | port lincoln
# Processing Record 23 of Set 5 | lompoc
# Processing Record 24 of Set 5 | sao miguel do araguaia
# Processing Record 25 of Set 5 | chapais
# Processing Record 26 of Set 5 | arlit
# Processing Record 27 of Set 5 | derzhavinsk
# Processing Record 28 of Set 5 | tazmalt
# Processing Record 29 of Set 5 | mitsamiouli
# Processing Record 30 of Set 5 | vao
# Processing Record 31 of Set 5 | wadi maliz
# Processing Record 32 of Set 5 | stephenville
# Processing Record 33 of Set 5 | nanortalik
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | yurla
# Processing Record 36 of Set 5 | touros
# Processing Record 37 of Set 5 | ksenyevka
# City not found. Skipping
# Processing Record 38 of Set 5 | hambantota
# Processing Record 39 of Set 5 | jiroft
# City not found. Skipping
# Processing Record 40 of Set 5 | waldheim
# Processing Record 41 of Set 5 | mar del plata
# Processing Record 42 of Set 5 | joshimath
# Processing Record 43 of Set 5 | bima
# Processing Record 44 of Set 5 | cadereyta
# Processing Record 45 of Set 5 | sinkat
# City not found. Skipping
# Processing Record 46 of Set 5 | mocuba
# Processing Record 47 of Set 5 | maragogi
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | great yarmouth
# Processing Record 50 of Set 5 | srednekolymsk
# Processing Record 1 of Set 6 | tutoia
# Processing Record 2 of Set 6 | aflu
# City not found. Skipping
# Processing Record 3 of Set 6 | grand gaube
# Processing Record 4 of Set 6 | pontes e lacerda
# Processing Record 5 of Set 6 | cabcab
# Processing Record 6 of Set 6 | bamora
# Processing Record 7 of Set 6 | kampot
# Processing Record 8 of Set 6 | nhulunbuy
# Processing Record 9 of Set 6 | bambous virieux
# Processing Record 10 of Set 6 | sandnessjoen
# Processing Record 11 of Set 6 | chokurdakh
# Processing Record 12 of Set 6 | bilma
# Processing Record 13 of Set 6 | kysyl-syr
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | oro valley
# Processing Record 16 of Set 6 | waddan
# Processing Record 17 of Set 6 | severo-kurilsk
# Processing Record 18 of Set 6 | vila velha
# Processing Record 19 of Set 6 | harnosand
# Processing Record 20 of Set 6 | cherskiy
# Processing Record 21 of Set 6 | fortuna
# Processing Record 22 of Set 6 | sangar
# Processing Record 23 of Set 6 | itapora
# Processing Record 24 of Set 6 | puerto el triunfo
# Processing Record 25 of Set 6 | mende
# Processing Record 26 of Set 6 | aykhal
# Processing Record 27 of Set 6 | pandan
# Processing Record 28 of Set 6 | mocambique
# City not found. Skipping
# Processing Record 29 of Set 6 | baruun-urt
# Processing Record 30 of Set 6 | chuguyevka
# Processing Record 31 of Set 6 | nizwa
# Processing Record 32 of Set 6 | marsa matruh
# Processing Record 33 of Set 6 | rockhampton
# Processing Record 34 of Set 6 | miami
# Processing Record 35 of Set 6 | sukabumi
# Processing Record 36 of Set 6 | ust-kut
# Processing Record 37 of Set 6 | ryotsu
# Processing Record 38 of Set 6 | san luis
# Processing Record 39 of Set 6 | chabahar
# Processing Record 40 of Set 6 | iskateley
# Processing Record 41 of Set 6 | mecca
# Processing Record 42 of Set 6 | taber
# Processing Record 43 of Set 6 | formoso do araguaia
# City not found. Skipping
# Processing Record 44 of Set 6 | gornopravdinsk
# Processing Record 45 of Set 6 | leningradskiy
# Processing Record 46 of Set 6 | la orilla
# Processing Record 47 of Set 6 | la ronge
# Processing Record 48 of Set 6 | camacupa
# Processing Record 49 of Set 6 | byron bay
# Processing Record 50 of Set 6 | zhaoyuan
# Processing Record 1 of Set 7 | filingue
# Processing Record 2 of Set 7 | sibu
# Processing Record 3 of Set 7 | gazanjyk
# Processing Record 4 of Set 7 | kepno
# Processing Record 5 of Set 7 | smithers
# Processing Record 6 of Set 7 | road town
# Processing Record 7 of Set 7 | conceicao do araguaia
# Processing Record 8 of Set 7 | sept-iles
# Processing Record 9 of Set 7 | guerrero negro
# Processing Record 10 of Set 7 | isangel
# Processing Record 11 of Set 7 | opuwo
# Processing Record 12 of Set 7 | chachapoyas
# Processing Record 13 of Set 7 | mount gambier
# Processing Record 14 of Set 7 | kawana waters
# City not found. Skipping
# Processing Record 15 of Set 7 | bayan
# Processing Record 16 of Set 7 | horn
# Processing Record 17 of Set 7 | bengkulu
# Processing Record 18 of Set 7 | castro
# Processing Record 19 of Set 7 | krasnoselkup
# Processing Record 20 of Set 7 | kidal
# Processing Record 21 of Set 7 | ilulissat
# Processing Record 22 of Set 7 | tabou
# Processing Record 23 of Set 7 | broken hill
# Processing Record 24 of Set 7 | bargal
# City not found. Skipping
# Processing Record 25 of Set 7 | longyearbyen
# Processing Record 26 of Set 7 | la peca
# Processing Record 27 of Set 7 | beloha
# Processing Record 28 of Set 7 | borgarnes
# Processing Record 29 of Set 7 | corpus christi
# Processing Record 30 of Set 7 | missoula
# Processing Record 31 of Set 7 | sao raimundo das mangabeiras
# Processing Record 32 of Set 7 | rorvik
# Processing Record 33 of Set 7 | takanosu
# Processing Record 34 of Set 7 | villa alemana
# Processing Record 35 of Set 7 | general roca
# Processing Record 36 of Set 7 | gold coast
# Processing Record 37 of Set 7 | murgab
# Processing Record 38 of Set 7 | maniitsoq
# Processing Record 39 of Set 7 | muros
# Processing Record 40 of Set 7 | tidore
# City not found. Skipping
# Processing Record 41 of Set 7 | attawapiskat
# City not found. Skipping
# Processing Record 42 of Set 7 | alta floresta
# Processing Record 43 of Set 7 | mmathubudukwane
# Processing Record 44 of Set 7 | denpasar
# Processing Record 45 of Set 7 | pasaco
# Processing Record 46 of Set 7 | sillod
# Processing Record 47 of Set 7 | great falls
# Processing Record 48 of Set 7 | pilar
# Processing Record 49 of Set 7 | sitka
# Processing Record 50 of Set 7 | dunedin
# Processing Record 1 of Set 8 | tazovskiy
# Processing Record 2 of Set 8 | cockburn harbour
# City not found. Skipping
# Processing Record 3 of Set 8 | youghal
# Processing Record 4 of Set 8 | masterton
# Processing Record 5 of Set 8 | urengoy
# Processing Record 6 of Set 8 | rio gallegos
# Processing Record 7 of Set 8 | dukat
# Processing Record 8 of Set 8 | koungou
# Processing Record 9 of Set 8 | havoysund
# Processing Record 10 of Set 8 | cabaiguan
# Processing Record 11 of Set 8 | nevers
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping
# Processing Record 13 of Set 8 | gizo
# Processing Record 14 of Set 8 | puerto colombia
# Processing Record 15 of Set 8 | myrtle grove
# Processing Record 16 of Set 8 | concarneau
# Processing Record 17 of Set 8 | pangoa
# Processing Record 18 of Set 8 | tarkwa
# Processing Record 19 of Set 8 | walvis bay
# Processing Record 20 of Set 8 | basay
# Processing Record 21 of Set 8 | plavsk
# Processing Record 22 of Set 8 | bilibino
# Processing Record 23 of Set 8 | umm lajj
# Processing Record 24 of Set 8 | port augusta
# Processing Record 25 of Set 8 | dharan
# Processing Record 26 of Set 8 | santa rosa de aguan
# Processing Record 27 of Set 8 | kavieng
# Processing Record 28 of Set 8 | vanderhoof
# Processing Record 29 of Set 8 | fomboni
# Processing Record 30 of Set 8 | hatillo
# Processing Record 31 of Set 8 | sentyabrskiy
# City not found. Skipping
# Processing Record 32 of Set 8 | dingle
# Processing Record 33 of Set 8 | del rio
# Processing Record 34 of Set 8 | znamenskoye
# Processing Record 35 of Set 8 | paamiut
# Processing Record 36 of Set 8 | sungaipenuh
# Processing Record 37 of Set 8 | ewo
# Processing Record 38 of Set 8 | cockburn town
# Processing Record 39 of Set 8 | taksimo
# Processing Record 40 of Set 8 | luanda
# Processing Record 41 of Set 8 | popondetta
# Processing Record 42 of Set 8 | caninde
# Processing Record 43 of Set 8 | teya
# Processing Record 44 of Set 8 | camacha
# Processing Record 45 of Set 8 | limbang
# Processing Record 46 of Set 8 | sabzevar
# Processing Record 47 of Set 8 | zhanaozen
# Processing Record 48 of Set 8 | cascais
# Processing Record 49 of Set 8 | kharovsk
# Processing Record 50 of Set 8 | puerto escondido
# Processing Record 1 of Set 9 | claveria
# Processing Record 2 of Set 9 | nguiu
# City not found. Skipping
# Processing Record 3 of Set 9 | kyra
# Processing Record 4 of Set 9 | pevek
# Processing Record 5 of Set 9 | jubayl
# City not found. Skipping
# Processing Record 6 of Set 9 | vanimo
# Processing Record 7 of Set 9 | port macquarie
# Processing Record 8 of Set 9 | sebring
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | huazolotitlan
# City not found. Skipping
# Processing Record 11 of Set 9 | santa isabel do rio negro
# Processing Record 12 of Set 9 | bathsheba
# Processing Record 13 of Set 9 | burica
# City not found. Skipping
# Processing Record 14 of Set 9 | lolua
# City not found. Skipping
# Processing Record 15 of Set 9 | biloela
# Processing Record 16 of Set 9 | rayon
# Processing Record 17 of Set 9 | omboue
# Processing Record 18 of Set 9 | chara
# Processing Record 19 of Set 9 | moskovskiy
# Processing Record 20 of Set 9 | rongcheng
# Processing Record 21 of Set 9 | talavera de la reina
# Processing Record 22 of Set 9 | nishihara
# Processing Record 23 of Set 9 | salta
# Processing Record 24 of Set 9 | marystown
# Processing Record 25 of Set 9 | cap malheureux
# Processing Record 26 of Set 9 | diapaga
# Processing Record 27 of Set 9 | vostok
# Processing Record 28 of Set 9 | jiuquan
# Processing Record 29 of Set 9 | storsteinnes
# Processing Record 30 of Set 9 | shakawe
# Processing Record 31 of Set 9 | woodward
# Processing Record 32 of Set 9 | sembe
# Processing Record 33 of Set 9 | gurgan
# City not found. Skipping
# Processing Record 34 of Set 9 | tolaga bay
# Processing Record 35 of Set 9 | taburi
# City not found. Skipping
# Processing Record 36 of Set 9 | umba
# Processing Record 37 of Set 9 | husavik
# Processing Record 38 of Set 9 | benito juarez
# Processing Record 39 of Set 9 | mitu
# Processing Record 40 of Set 9 | sao filipe
# Processing Record 41 of Set 9 | cartagena
# Processing Record 42 of Set 9 | san vicente
# Processing Record 43 of Set 9 | temaraia
# City not found. Skipping
# Processing Record 44 of Set 9 | marcona
# City not found. Skipping
# Processing Record 45 of Set 9 | tokmak
# Processing Record 46 of Set 9 | porto novo
# Processing Record 47 of Set 9 | sobolevo
# Processing Record 48 of Set 9 | vestmannaeyjar
# Processing Record 49 of Set 9 | sanary-sur-mer
# Processing Record 50 of Set 9 | kaduna
# Processing Record 1 of Set 10 | ahipara
# Processing Record 2 of Set 10 | nemuro
# Processing Record 3 of Set 10 | chagda
# City not found. Skipping
# Processing Record 4 of Set 10 | gouyave
# Processing Record 5 of Set 10 | palmer
# Processing Record 6 of Set 10 | posse
# Processing Record 7 of Set 10 | torbay
# Processing Record 8 of Set 10 | labuhan
# Processing Record 9 of Set 10 | leh
# Processing Record 10 of Set 10 | ponta do sol
# Processing Record 11 of Set 10 | price
# Processing Record 12 of Set 10 | san felipe
# Processing Record 13 of Set 10 | ust-koksa
# Processing Record 14 of Set 10 | ribeira brava
# Processing Record 15 of Set 10 | tungor
# Processing Record 16 of Set 10 | waitara
# Processing Record 17 of Set 10 | labutta
# City not found. Skipping
# Processing Record 18 of Set 10 | kribi
# Processing Record 19 of Set 10 | coahuayana
# Processing Record 20 of Set 10 | katete
# Processing Record 21 of Set 10 | bokspits
# City not found. Skipping
# Processing Record 22 of Set 10 | grand centre
# City not found. Skipping
# Processing Record 23 of Set 10 | darhan
# Processing Record 24 of Set 10 | sinnamary
# Processing Record 25 of Set 10 | peniche
# Processing Record 26 of Set 10 | zhigansk
# Processing Record 27 of Set 10 | igarka
# Processing Record 28 of Set 10 | flin flon
# Processing Record 29 of Set 10 | maldonado
# Processing Record 30 of Set 10 | wenling
# Processing Record 31 of Set 10 | santa fe
# Processing Record 32 of Set 10 | oranjestad
# Processing Record 33 of Set 10 | deputatskiy
# Processing Record 34 of Set 10 | matara
# Processing Record 35 of Set 10 | ramnicu sarat
# Processing Record 36 of Set 10 | bethel
# Processing Record 37 of Set 10 | praia
# Processing Record 38 of Set 10 | mackay
# Processing Record 39 of Set 10 | jutai
# Processing Record 40 of Set 10 | lewiston
# Processing Record 41 of Set 10 | pisco
# Processing Record 42 of Set 10 | jijiga
# Processing Record 43 of Set 10 | cedar city
# Processing Record 44 of Set 10 | havelock
# Processing Record 45 of Set 10 | ust-maya
# Processing Record 46 of Set 10 | flinders
# Processing Record 47 of Set 10 | santa cruz de la palma
# Processing Record 48 of Set 10 | luorong
# Processing Record 49 of Set 10 | orlik
# Processing Record 50 of Set 10 | hegra
# Processing Record 1 of Set 11 | mana
# Processing Record 2 of Set 11 | rafsanjan
# Processing Record 3 of Set 11 | gazni
# City not found. Skipping
# Processing Record 4 of Set 11 | sibolga
# Processing Record 5 of Set 11 | alice springs
# Processing Record 6 of Set 11 | bubaque
# Processing Record 7 of Set 11 | la rioja
# Processing Record 8 of Set 11 | port hedland
# Processing Record 9 of Set 11 | hovd
# Processing Record 10 of Set 11 | antofagasta
# Processing Record 11 of Set 11 | aleksandrovka
# Processing Record 12 of Set 11 | port keats
# Processing Record 13 of Set 11 | burkburnett
# Processing Record 14 of Set 11 | namibe
# Processing Record 15 of Set 11 | aanekoski
# Processing Record 16 of Set 11 | aurangabad
# Processing Record 17 of Set 11 | golden
# Processing Record 18 of Set 11 | rioja
# Processing Record 19 of Set 11 | sechura
# Processing Record 20 of Set 11 | lazaro cardenas
# Processing Record 21 of Set 11 | riyadh
# Processing Record 22 of Set 11 | homer
# Processing Record 23 of Set 11 | sorvag
# City not found. Skipping
# Processing Record 24 of Set 11 | smiltene
# Processing Record 25 of Set 11 | olafsvik
# Processing Record 26 of Set 11 | bay-khaak
# Processing Record 27 of Set 11 | margate
# Processing Record 28 of Set 11 | yakima
# Processing Record 29 of Set 11 | mubi
# Processing Record 30 of Set 11 | kirakira
# Processing Record 31 of Set 11 | yelkhovka
# Processing Record 32 of Set 11 | pacifica
# Processing Record 33 of Set 11 | zhezkazgan
# Processing Record 34 of Set 11 | diez
# Processing Record 35 of Set 11 | hagersville
# Processing Record 36 of Set 11 | brae
# Processing Record 37 of Set 11 | mys shmidta
# City not found. Skipping
# Processing Record 38 of Set 11 | sarkand
# Processing Record 39 of Set 11 | xixiang
# Processing Record 40 of Set 11 | kenai
# Processing Record 41 of Set 11 | wangou
# Processing Record 42 of Set 11 | buraydah
# Processing Record 43 of Set 11 | pondicherry
# Processing Record 44 of Set 11 | makat
# Processing Record 45 of Set 11 | san matias
# Processing Record 46 of Set 11 | rosarito
# Processing Record 47 of Set 11 | guarapari
# Processing Record 48 of Set 11 | khilok
# Processing Record 49 of Set 11 | san ramon
# Processing Record 50 of Set 11 | disraeli
# Processing Record 1 of Set 12 | key largo
# Processing Record 2 of Set 12 | westport
# Processing Record 3 of Set 12 | karratha
# Processing Record 4 of Set 12 | ixtapa
# Processing Record 5 of Set 12 | marawi
# Processing Record 6 of Set 12 | nambiyur
# Processing Record 7 of Set 12 | kolomak
# Processing Record 8 of Set 12 | wageningen
# Processing Record 9 of Set 12 | wajima
# Processing Record 10 of Set 12 | butzbach
# Processing Record 11 of Set 12 | balkanabat
# Processing Record 12 of Set 12 | carutapera
# Processing Record 13 of Set 12 | zhuhai
# Processing Record 14 of Set 12 | loanda
# Processing Record 15 of Set 12 | saleaula
# City not found. Skipping
# Processing Record 16 of Set 12 | dejen
# Processing Record 17 of Set 12 | yar-sale
# Processing Record 18 of Set 12 | dekoa
# City not found. Skipping
# Processing Record 19 of Set 12 | azanka
# Processing Record 20 of Set 12 | fukue
# Processing Record 21 of Set 12 | micheweni
# Processing Record 22 of Set 12 | nassau
# Processing Record 23 of Set 12 | ostrovnoy
# Processing Record 24 of Set 12 | eltham
# Processing Record 25 of Set 12 | wanaka
# Processing Record 26 of Set 12 | awjilah
# Processing Record 27 of Set 12 | amderma
# City not found. Skipping
# Processing Record 28 of Set 12 | nisia floresta
# Processing Record 29 of Set 12 | mercedes
# Processing Record 30 of Set 12 | robertsport
# Processing Record 31 of Set 12 | kopervik
# Processing Record 32 of Set 12 | sanandaj
# Processing Record 33 of Set 12 | pangani
# Processing Record 34 of Set 12 | ola
# Processing Record 35 of Set 12 | illapel
# Processing Record 36 of Set 12 | benguela
# Processing Record 37 of Set 12 | pitimbu
# Processing Record 38 of Set 12 | safford
# Processing Record 39 of Set 12 | aasiaat
# Processing Record 40 of Set 12 | ginda
# Processing Record 41 of Set 12 | savannah bight
# Processing Record 42 of Set 12 | kasongo
# Processing Record 43 of Set 12 | mergui
# City not found. Skipping
# Processing Record 44 of Set 12 | oreanda
# City not found. Skipping
# Processing Record 45 of Set 12 | san quintin
# Processing Record 46 of Set 12 | mersing
# Processing Record 47 of Set 12 | sydney
# Processing Record 48 of Set 12 | rungata
# City not found. Skipping
# Processing Record 49 of Set 12 | coihaique
# Processing Record 50 of Set 12 | trincomalee
# Processing Record 1 of Set 13 | kemijarvi
# Processing Record 2 of Set 13 | teguise
# Processing Record 3 of Set 13 | bobon
# Processing Record 4 of Set 13 | aguimes
# Processing Record 5 of Set 13 | kalulushi
# Processing Record 6 of Set 13 | mbaiki
# Processing Record 7 of Set 13 | newport
# Processing Record 8 of Set 13 | maroantsetra
# Processing Record 9 of Set 13 | jam sahib
# Processing Record 10 of Set 13 | tuggurt
# City not found. Skipping
# Processing Record 11 of Set 13 | kamaishi
# Processing Record 12 of Set 13 | ziro
# Processing Record 13 of Set 13 | tsumeb
# Processing Record 14 of Set 13 | norsup
# Processing Record 15 of Set 13 | svetlogorsk
# Processing Record 16 of Set 13 | naryan-mar
# Processing Record 17 of Set 13 | sao felix do xingu
# Processing Record 18 of Set 13 | cortes
# Processing Record 19 of Set 13 | deming
# Processing Record 20 of Set 13 | kaeo
# Processing Record 21 of Set 13 | port-cartier
# Processing Record 22 of Set 13 | waycross
# Processing Record 23 of Set 13 | tabiauea
# City not found. Skipping
# Processing Record 24 of Set 13 | orje
# Processing Record 25 of Set 13 | murray bridge
# Processing Record 26 of Set 13 | puerto del rosario
# Processing Record 27 of Set 13 | el triunfo
# Processing Record 28 of Set 13 | itarema
# Processing Record 29 of Set 13 | caldas novas
# Processing Record 30 of Set 13 | freeport
# Processing Record 31 of Set 13 | birjand
# Processing Record 32 of Set 13 | aljezur
# Processing Record 33 of Set 13 | sisimiut
# Processing Record 34 of Set 13 | alberton
# Processing Record 35 of Set 13 | labrea
# Processing Record 36 of Set 13 | abha
# Processing Record 37 of Set 13 | kavaratti
# Processing Record 38 of Set 13 | salumbar
# Processing Record 39 of Set 13 | xuddur
# Processing Record 40 of Set 13 | jiayuguan
# Processing Record 41 of Set 13 | muravlenko
# Processing Record 42 of Set 13 | hobbs
# Processing Record 43 of Set 13 | riberalta
# Processing Record 44 of Set 13 | bocas del toro
# Processing Record 45 of Set 13 | maralal
# Processing Record 46 of Set 13 | kulu
# Processing Record 47 of Set 13 | hai duong
# Processing Record 48 of Set 13 | guaymas
# Processing Record 49 of Set 13 | gat
# Processing Record 50 of Set 13 | agirish
# Processing Record 1 of Set 14 | nawa
# Processing Record 2 of Set 14 | makasar
# Processing Record 3 of Set 14 | hami
# Processing Record 4 of Set 14 | pedernales
# Processing Record 5 of Set 14 | harper
# Processing Record 6 of Set 14 | olinda
# Processing Record 7 of Set 14 | sambava
# Processing Record 8 of Set 14 | sorland
# Processing Record 9 of Set 14 | quatre cocos
# Processing Record 10 of Set 14 | abu dhabi
# Processing Record 11 of Set 14 | xining
# Processing Record 12 of Set 14 | bonthe
# Processing Record 13 of Set 14 | college
# Processing Record 14 of Set 14 | timra
# Processing Record 15 of Set 14 | utiroa
# City not found. Skipping
# Processing Record 16 of Set 14 | puerto leguizamo
# Processing Record 17 of Set 14 | mamallapuram
# Processing Record 18 of Set 14 | rotterdam
# Processing Record 19 of Set 14 | fallon
# Processing Record 20 of Set 14 | mikhaylovka
# Processing Record 21 of Set 14 | petersburg
# Processing Record 22 of Set 14 | ondjiva
# Processing Record 23 of Set 14 | makakilo city
# Processing Record 24 of Set 14 | mansa
# Processing Record 25 of Set 14 | benghazi
# Processing Record 26 of Set 14 | zyryanka
# Processing Record 27 of Set 14 | hobyo
# Processing Record 28 of Set 14 | kutum
# Processing Record 29 of Set 14 | kropotkin
# Processing Record 30 of Set 14 | salalah
# Processing Record 31 of Set 14 | ghanzi
# Processing Record 32 of Set 14 | tura
# Processing Record 33 of Set 14 | muroto
# Processing Record 34 of Set 14 | russkaya polyana
# Processing Record 35 of Set 14 | azimur
# City not found. Skipping
# Processing Record 36 of Set 14 | cayenne
# Processing Record 37 of Set 14 | codrington
# Processing Record 38 of Set 14 | dawei
# Processing Record 39 of Set 14 | koson
# Processing Record 40 of Set 14 | aguie
# Processing Record 41 of Set 14 | yenangyaung
# Processing Record 42 of Set 14 | san antonio
# Processing Record 43 of Set 14 | belmonte
# Processing Record 44 of Set 14 | tono
# Processing Record 45 of Set 14 | akyab
# Processing Record 46 of Set 14 | bjornevatn
# Processing Record 47 of Set 14 | jerez
# Processing Record 48 of Set 14 | kieta
# Processing Record 49 of Set 14 | senador jose porfirio
# Processing Record 50 of Set 14 | bolekhiv
# Processing Record 1 of Set 15 | teguldet
# Processing Record 2 of Set 15 | namwala
# Processing Record 3 of Set 15 | fatehpur
# Processing Record 4 of Set 15 | saint-pierre
# Processing Record 5 of Set 15 | tenabo
# Processing Record 6 of Set 15 | cairns
# Processing Record 7 of Set 15 | payo
# Processing Record 8 of Set 15 | witham
# Processing Record 9 of Set 15 | maracaju
# Processing Record 10 of Set 15 | the pas
# Processing Record 11 of Set 15 | nykoping
# Processing Record 12 of Set 15 | sorong
# Processing Record 13 of Set 15 | port blair
# Processing Record 14 of Set 15 | wawa
# Processing Record 15 of Set 15 | sayyan
# Processing Record 16 of Set 15 | ambilobe
# Processing Record 17 of Set 15 | brigantine
# Processing Record 18 of Set 15 | parral
# Processing Record 19 of Set 15 | belaya gora
# Processing Record 20 of Set 15 | matamoros
# Processing Record 21 of Set 15 | pauini
# Processing Record 22 of Set 15 | maloshuyka
# City not found. Skipping
# Processing Record 23 of Set 15 | meulaboh
# Processing Record 24 of Set 15 | bossembele
# City not found. Skipping
# Processing Record 25 of Set 15 | mentok
# City not found. Skipping
# Processing Record 26 of Set 15 | deshnok
# Processing Record 27 of Set 15 | acarau
# Processing Record 28 of Set 15 | los llanos de aridane
# Processing Record 29 of Set 15 | kangaatsiaq
# Processing Record 30 of Set 15 | rawson
# Processing Record 31 of Set 15 | dabakala
# Processing Record 32 of Set 15 | cooma
# Processing Record 33 of Set 15 | saint-francois
# Processing Record 34 of Set 15 | russell
# Processing Record 35 of Set 15 | faya
# Processing Record 36 of Set 15 | providencia
# ---
# Data Retrival Completed
# ---

# %%
len(city_data)
# Out:
# 681

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Hithadhoo      MV  -0.6000   73.0833     85.32        73
# 1           Rikitea      PF -23.1203 -134.9692     76.37        71
# 2           Mataura      NZ -46.1927  168.8643     57.47        87
# 3         Busselton      AU -33.6500  115.3333     61.05        82
# 4     Saint Anthony      US  45.0205  -93.2180     46.00        87
# ..              ...     ...      ...       ...       ...       ...
# 676           Cooma      AU -36.2333  149.1333     52.12        63
# 677  Saint-Francois      FR  46.4154    3.9054     45.68        87
# 678         Russell      US  32.3502  -85.1999     80.96        63
# 679            Faya      SA  18.3851   42.4509     66.31        53
# 680     Providencia      MX  28.7167 -111.5833     92.21        26
#
#      Cloudiness  Wind Speed Current Description
# 0           100       16.33     overcast clouds
# 1            12        5.64          few clouds
# 2            12        3.36          few clouds
# 3            67        1.61       broken clouds
# 4           100       17.27     overcast clouds
# ..          ...         ...                 ...
# 676          14        1.92          few clouds
# 677           0        1.14           clear sky
# 678          20        5.75          few clouds
# 679          15        2.46          few clouds
# 680           0       20.56           clear sky
#
# [681 rows x 9 columns]

# %%
output_data_file="WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
